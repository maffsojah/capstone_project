# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from faker import Faker
from random import random

import pandas as pd
import numpy as np
import csv
import random

# %%
fake = Faker()

# %%
accounts_list = ['Savings', 'Current']
sex_list = ['Male', 'Female']


# Fake Data Generator function
 
def fake_data():
    return{'Name': fake.name(), 
           'Gender': random.choice(sex_list),
           'Address': fake.street_address(), 
           'Nationality': 'Zimbabwean', 
           'Account_Type': random.choice(accounts_list), 
           'Age': random.randint(0, 2), 
           'Education': random.random() > 0.5, 
           'Employment': random.randint(0, 2),
           'Salary': random.randint(0, 2),
           'Employer_Stability': random.random() > 0.5,
           'Consistency': random.random() > 0.5,
           'Balance': random.randint(0, 2),
           'Residential_Status': random.random() > 0.5
          }


df = pd.DataFrame([fake_data() for _ in range(1000)], columns = ['Name', 'Gender', 'Address', 'Nationality', 'Account_Type', 'Age','Education', 'Employment', 'Salary', 'Employer_Stability', 'Consistency', 'Balance', 'Residential_Status'])
df.index.names = ['Customer_ID']

# %%
# Print the DataFrame to csv file

#df.to_csv('../datasets/dummyTest.csv')

# %%
df
# Out:
#                                  Name  Gender  \
# Customer_ID
# 0                        Jill Calhoun  Female
# 1                           Lori Neal    Male
# 2                    Mr. Ernest Brown    Male
# 3            Mr. Ronnie Stevenson DVM    Male
# 4                     Patricia Taylor    Male
# 5                         Donald West  Female
# 6                      Anthony Church  Female
# 7                    Diamond Chambers  Female
# 8                     Steven Shepherd  Female
# 9                         Robert Howe  Female
# 10                        Brandi Boyd    Male
# 11                        Casey Quinn    Male
# 12                    Jennifer Suarez    Male
# 13                     Donald Hawkins    Male
# 14                      Willie Hoover    Male
# 15                         Tina Jones    Male
# 16                     Deborah Sexton    Male
# 17                        Adam Graham  Female
# 18                         Cole Stark    Male
# 19                  Kristy Livingston    Male
# 20                   Zachary Anderson  Female
# 21                        Erin Jacobs  Female
# 22                      Adrian Becker    Male
# 23                     James Cummings  Female
# 24                   Jennifer Bennett    Male
# 25                        Ronnie Gray    Male
# 26                  Kimberly Campbell    Male
# 27                 Michael Washington  Female
# 28                      Joshua Brewer  Female
# 29                           Wyatt Li  Female
# ...                               ...     ...
# 970                           Mary Wu    Male
# 971                        Kyle Allen  Female
# 972                 Stephen Henderson    Male
# 973                      Keith Austin  Female
# 974                     Justin Branch    Male
# 975                       Shelly Reed    Male
# 976                Jacqueline Patrick  Female
# 977                 Kimberly Figueroa  Female
# 978                     Kelly Johnson    Male
# 979                   Victoria Bailey  Female
# 980                 Gabriel Hernandez  Female
# 981                    Charles Duncan    Male
# 982                Andrew Browning MD  Female
# 983                       Ashley Luna    Male
# 984                 Jennifer Morrison  Female
# 985                     Joshua Harris  Female
# 986                      Kayla Norris    Male
# 987                       David Solis    Male
# 988                Katherine Griffith    Male
# 989                     Brandon Clark    Male
# 990                 Dr. Jeffery Reyes    Male
# 991                      Tiffany Pham  Female
# 992                        Mia Stokes  Female
# 993                   Joshua Thompson  Female
# 994                     Anthony Short  Female
# 995                       Karina King  Female
# 996                    James Williams  Female
# 997                    Jordan Vasquez  Female
# 998                    Vincent Miller    Male
# 999                   Christine Jones  Female
#
#                                           Address Nationality Account_Type  \
# Customer_ID
# 0                            4346 Jonathan Stream  Zimbabwean      Savings
# 1                                 656 Kayla Drive  Zimbabwean      Current
# 998                               53070 Chen Lock  Zimbabwean      Current
# 999                                474 White Mall  Zimbabwean      Current
#
#              Age Education  Employment  Salary Employer_Stability Consistency  \
# Customer_ID
# 0              1      True           2       2              False       False
# 1              2     False           2       1              False        True
# 2              2      True           2       2              False        True
# 3              0     False           0       1               True       False
# 4              0     False           1       0              False       False
# 5              1      True           0       1              False       False
# 6              2     False           0       1               True       False
# 7              2     False           0       2               True       False
# 8              2      True           0       2              False       False
# 9              1     False           1       2              False        True
# 10             2      True           2       0               True        True
# 11             1      True           2       2               True       False
# 12             1     False           0       1               True       False
# 13             2      True           2       1               True        True
# 14             2      True           0       0              False        True
# 15             1     False           2       1               True       False
# 16             2      True           2       1               True        True
# 17             1     False           2       1              False        True
# 18             1      True           0       1               True       False
# 19             2     False           0       0               True        True
# 20             0      True           0       2              False       False
# 21             0     False           1       1              False        True
# 22             2     False           1       0              False       False
# 23             0     False           1       0              False        True
# 24             0      True           2       2              False       False
# 25             1     False           2       0               True        True
# 26             1     False           1       2              False       False
# 27             2      True           1       0               True        True
# 28             0     False           0       0               True       False
# 29             1      True           1       2              False       False
# ...          ...       ...         ...     ...                ...         ...
# 970            2     False           0       0              False        True
# 971            1     False           2       1               True       False
# 972            0     False           0       1              False       False
# 973            2     False           2       0               True        True
# 974            0      True           1       2               True       False
# 975            1      True           0       0              False        True
# 976            0     False           1       2              False       False
# 977            2     False           1       1              False        True
# 978            1     False           0       0              False       False
# 979            2      True           2       2               True       False
# 980            2      True           0       0              False       False
# 981            0      True           0       1               True        True
# 982            2     False           2       0               True        True
# 983            2      True           0       2              False       False
# 984            0     False           2       1              False       False
# 985            0      True           2       1               True        True
# 986            1      True           1       0               True        True
# 987            1      True           0       0               True        True
# 988            1     False           2       0              False       False
# 989            0     False           2       1               True        True
# 990            1      True           0       2               True        True
# 991            2      True           1       2              False       False
# 992            0      True           2       1              False       False
# 993            2     False           2       1              False       False
# 994            2      True           1       1              False       False
# 995            1      True           2       0               True        True
# 996            1      True           1       1              False        True
# 997            2     False           0       1              False        True
# 998            1      True           1       1               True        True
# 999            2      True           2       1               True        True
#
#              Balance Residential_Status
# Customer_ID
# 0                  1              False
# 1                  1              False
# 2                  2              False
# 3                  2              False
# 4                  1              False
# 5                  2               True
# 6                  2              False
# 7                  1              False
# 8                  1               True
# 9                  0              False
# 10                 1              False
# 11                 2               True
# 12                 1               True
# 13                 2               True
# 14                 2               True
# 15                 2              False
# 16                 0              False
# 17                 2              False
# 18                 2              False
# 19                 0               True
# 20                 0               True
# 21                 2              False
# 22                 1              False
# 23                 0               True
# 24                 1              False
# 25                 1               True
# 26                 0               True
# 27                 2              False
# 28                 2              False
# 29                 2               True
# ...              ...                ...
# 970                0               True
# 971                2               True
# 972                0              False
# 973                1              False
# 974                2               True
# 975                1              False
# 976                0               True
# 977                2              False
# 978                0               True
# 979                2              False
# 980                1              False
# 981                1               True
# 982                1               True
# 983                2              False
# 984                0              False
# 985                2              False
# 986                2               True
# 987                2              False
# 988                2              False
# 989                1               True
# 990                2               True
# 991                0               True
# 992                1              False
# 993                1              False
# 994                1              False
# 995                1               True
# 996                0               True
# 997                1              False
# 998                2               True
# 999                0              False
#
# [1000 rows x 13 columns]
