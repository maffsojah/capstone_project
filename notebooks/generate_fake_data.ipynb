# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from faker import Faker
from random import random
from sklearn.datasets import make_classification

import pandas as pd
import numpy as np
import csv
import random

# %%
fake = Faker()

# %%
# changing column data with faker

accounts_list = ['Savings', 'Current']
sex_list = ['Male', 'Female']
# names_list = [fake.name_female(), fake.name_male()]

# Fake Data Generator function
 
def fake_data():
    return{'Name': fake.name(), 
           'Gender': random.choice(sex_list),
           'Address': fake.street_address(), 
           'Nationality': 'Zimbabwean', 
           'Account_Type': random.choice(accounts_list), 
           'Age': random.randint(0, 2), 
           'Education': random.random() > 0.5, 
           'Employment': random.randint(0, 2),
           'Salary': random.randint(0, 2),
           'Employer_Stability': random.random() > 0.5,
           'Consistency': random.random() > 0.5,
           'Balance': random.randint(0, 2),
           'Residential_Status': random.random() > 0.5
          }


df = pd.DataFrame([fake_data() for _ in range(100000)], columns = ['Name', 'Gender', 'Address', 'Nationality', 'Account_Type', 'Age','Education', 'Employment', 'Salary', 'Employer_Stability', 'Consistency', 'Balance', 'Residential_Status'])
df.index.names = ['Customer_ID']

# %%
df.head()
# Out:
#                           Name  Gender                     Address  \
# Customer_ID
# 0            Michelle Anderson    Male  630 Andrea Island Apt. 990
# 1                   Mary Owens  Female          0854 Vasquez River
# 2                  Anna Cooper    Male       8443 Rodriguez Manors
# 3                   Paul Davis    Male             380 Franco Isle
# 4                 Sergio Clark  Female           605 White Gateway
#
#             Nationality Account_Type  Age Education  Employment  Salary  \
# Customer_ID
# 0            Zimbabwean      Savings    1     False           2       0
# 1            Zimbabwean      Current    2      True           0       1
# 2            Zimbabwean      Savings    2     False           2       1
# 3            Zimbabwean      Savings    0      True           2       0
# 4            Zimbabwean      Current    2      True           2       1
#
#             Employer_Stability Consistency  Balance Residential_Status
# Customer_ID
# 0                         True       False        2               True
# 1                        False       False        1              False
# 2                         True        True        0               True
# 3                        False        True        2              False
# 4                         True       False        0               True

# %%
# Creates ['Service_Level'] column with either 0 for Silver, 1 for Gold or 2 for Platinum Level 

df['Service_Level'] = np.where((df['Age']==1)&(df['Education']==True)&(df['Employment']==2)&(df['Salary']==0)&(df['Employer_Stability']==False)&(df['Consistency']==True)&(df['Balance']==0)&(df['Residential_Status']==False), 0,
                               (np.where((df['Age']==1)&(df['Education']==True)&(df['Employment']==2)&(df['Salary']==2)&(df['Employer_Stability']==False)&(df['Consistency']==True)&(df['Balance']==2)&(df['Residential_Status']==True), 2, 1)))

# %%
# rows where Service_Level is not 0

df[df['Service_Level'] == 2]
# Out:
#                             Name  Gender                            Address  \
# Customer_ID
# 1015             Matthew Charles  Female                  19679 Pitts Curve
# 2811                 David Lloyd    Male           532 Henry Cove Suite 898
# 4018                  Frank Wong  Female         5396 Kyle Parkway Apt. 403
# 4929                  Amber King    Male                  1793 Gary Highway
# 7998                 James Adams  Female                   52931 Tyler Port
# 8224                 Jaime Davis    Male   841 Catherine Crescent Suite 460
# 9501                 Max Jackson  Female                  053 West Parkways
# 9542                 Pedro Baker  Female          5004 Petty Hills Apt. 324
# 99185           Cassandra Morris    Male       54166 Nicholas Isle Apt. 439
# 99870                Terry Allen  Female              587 Daugherty Prairie
#
#             Nationality Account_Type  Age Education  Employment  Salary  \
# Customer_ID
# 1015         Zimbabwean      Current    1      True           2       2
# 2811         Zimbabwean      Savings    1      True           2       2
# 4018         Zimbabwean      Savings    1      True           2       2
# 4929         Zimbabwean      Current    1      True           2       2
# 7998         Zimbabwean      Savings    1      True           2       2
# 8224         Zimbabwean      Savings    1      True           2       2
# 9501         Zimbabwean      Savings    1      True           2       2
# 9542         Zimbabwean      Current    1      True           2       2
# 11592        Zimbabwean      Current    1      True           2       2
# 11844        Zimbabwean      Savings    1      True           2       2
# 13556        Zimbabwean      Current    1      True           2       2
# 15245        Zimbabwean      Savings    1      True           2       2
# 16252        Zimbabwean      Current    1      True           2       2
# 16731        Zimbabwean      Current    1      True           2       2
# 18299        Zimbabwean      Current    1      True           2       2
# 18521        Zimbabwean      Savings    1      True           2       2
# 19601        Zimbabwean      Current    1      True           2       2
# 20275        Zimbabwean      Savings    1      True           2       2
# 22381        Zimbabwean      Current    1      True           2       2
# 23121        Zimbabwean      Savings    1      True           2       2
# 23450        Zimbabwean      Current    1      True           2       2
# 23526        Zimbabwean      Savings    1      True           2       2
# 24726        Zimbabwean      Savings    1      True           2       2
# 27955        Zimbabwean      Current    1      True           2       2
# 33165        Zimbabwean      Current    1      True           2       2
# 33430        Zimbabwean      Current    1      True           2       2
# 34040        Zimbabwean      Current    1      True           2       2
# 35986        Zimbabwean      Current    1      True           2       2
# 37824        Zimbabwean      Current    1      True           2       2
# 38472        Zimbabwean      Savings    1      True           2       2
# ...                 ...          ...  ...       ...         ...     ...
# 65518        Zimbabwean      Savings    1      True           2       2
# 68208        Zimbabwean      Savings    1      True           2       2
# 69036        Zimbabwean      Savings    1      True           2       2
# 69579        Zimbabwean      Current    1      True           2       2
# 70972        Zimbabwean      Current    1      True           2       2
# 75510        Zimbabwean      Savings    1      True           2       2
# 77095        Zimbabwean      Current    1      True           2       2
# 79778        Zimbabwean      Current    1      True           2       2
# 80106        Zimbabwean      Current    1      True           2       2
# 80268        Zimbabwean      Savings    1      True           2       2
# 80871        Zimbabwean      Savings    1      True           2       2
# 81208        Zimbabwean      Current    1      True           2       2
# 81872        Zimbabwean      Savings    1      True           2       2
# 82539        Zimbabwean      Savings    1      True           2       2
# 83503        Zimbabwean      Current    1      True           2       2
# 83548        Zimbabwean      Savings    1      True           2       2
# 85388        Zimbabwean      Savings    1      True           2       2
# 86142        Zimbabwean      Current    1      True           2       2
# 87376        Zimbabwean      Current    1      True           2       2
# 88895        Zimbabwean      Current    1      True           2       2
# 89232        Zimbabwean      Savings    1      True           2       2
# 91419        Zimbabwean      Current    1      True           2       2
# 92587        Zimbabwean      Savings    1      True           2       2
# 93695        Zimbabwean      Savings    1      True           2       2
# 94048        Zimbabwean      Current    1      True           2       2
# 94501        Zimbabwean      Savings    1      True           2       2
# 94676        Zimbabwean      Savings    1      True           2       2
# 98846        Zimbabwean      Current    1      True           2       2
# 99185        Zimbabwean      Savings    1      True           2       2
# 99870        Zimbabwean      Savings    1      True           2       2
#
#             Employer_Stability Consistency  Balance Residential_Status  \
# Customer_ID
# 1015                     False        True        2               True
# 2811                     False        True        2               True
# 4018                     False        True        2               True
# 4929                     False        True        2               True
# 7998                     False        True        2               True
# 8224                     False        True        2               True
# 9501                     False        True        2               True
# 9542                     False        True        2               True
# 11592                    False        True        2               True
# 11844                    False        True        2               True
# 13556                    False        True        2               True
# 15245                    False        True        2               True
# 16252                    False        True        2               True
# 16731                    False        True        2               True
# 18299                    False        True        2               True
# 18521                    False        True        2               True
# 19601                    False        True        2               True
# 20275                    False        True        2               True
# 22381                    False        True        2               True
# 23121                    False        True        2               True
# 23450                    False        True        2               True
# 23526                    False        True        2               True
# 24726                    False        True        2               True
# 27955                    False        True        2               True
# 33165                    False        True        2               True
# 33430                    False        True        2               True
# 34040                    False        True        2               True
# 35986                    False        True        2               True
# 37824                    False        True        2               True
# 38472                    False        True        2               True
# ...                        ...         ...      ...                ...
# 65518                    False        True        2               True
# 68208                    False        True        2               True
# 69036                    False        True        2               True
# 69579                    False        True        2               True
# 70972                    False        True        2               True
# 75510                    False        True        2               True
# 77095                    False        True        2               True
# 79778                    False        True        2               True
# 80106                    False        True        2               True
# 80268                    False        True        2               True
# 80871                    False        True        2               True
# 81208                    False        True        2               True
# 81872                    False        True        2               True
# 82539                    False        True        2               True
# 83503                    False        True        2               True
# 83548                    False        True        2               True
# 85388                    False        True        2               True
# 86142                    False        True        2               True
# 87376                    False        True        2               True
# 88895                    False        True        2               True
# 89232                    False        True        2               True
# 91419                    False        True        2               True
# 92587                    False        True        2               True
# 93695                    False        True        2               True
# 94048                    False        True        2               True
# 94501                    False        True        2               True
# 94676                    False        True        2               True
# 98846                    False        True        2               True
# 99185                    False        True        2               True
# 99870                    False        True        2               True
#
#              Service_Level
# Customer_ID
# 1015                     2
# 2811                     2
# 4018                     2
# 4929                     2
# 7998                     2
# 8224                     2
# 9501                     2
# 9542                     2
# 11592                    2
# 11844                    2
# 13556                    2
# 15245                    2
# 16252                    2
# 16731                    2
# 18299                    2
# 18521                    2
# 19601                    2
# 20275                    2
# 22381                    2
# 23121                    2
# 23450                    2
# 23526                    2
# 24726                    2
# 27955                    2
# 33165                    2
# 33430                    2
# 34040                    2
# 35986                    2
# 37824                    2
# 38472                    2
# ...                    ...
# 65518                    2
# 68208                    2
# 69036                    2
# 69579                    2
# 70972                    2
# 75510                    2
# 77095                    2
# 79778                    2
# 80106                    2
# 80268                    2
# 80871                    2
# 81208                    2
# 81872                    2
# 82539                    2
# 83503                    2
# 83548                    2
# 85388                    2
# 86142                    2
# 87376                    2
# 88895                    2
# 89232                    2
# 91419                    2
# 92587                    2
# 93695                    2
# 94048                    2
# 94501                    2
# 94676                    2
# 98846                    2
# 99185                    2
# 99870                    2
#
# [75 rows x 14 columns]

# %%
# Print the DataFrame to csv file

df.to_csv('train_data.csv')
